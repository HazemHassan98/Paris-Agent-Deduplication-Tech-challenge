# %% [markdown]
#  # Paris Agent Deduplication Challenge
# This notebook demonstrates how to load data from MongoDB, perform data cleaning, and deduplicate records using fuzzy matching. Adjust the database and collection names as needed.

# %%
# !pip install pymongo

# %%
# !pip install rapidfuzz

# %% [markdown]
# # Import required libraries

# %%
# Import required libraries
import pymongo
import pandas as pd
import re
from rapidfuzz import fuzz

# %% [markdown]
# ## 1. Connect to MongoDB

# %%
conn_str = "mongodb://hiring:12341234@srv07.properbird.com:27017/"
client = pymongo.MongoClient(conn_str)
db = client['realEstateFr']
collection = db['agentSampleHiring']

# %% [markdown]
# # 2. Load the Data

# %%
data = list(collection.find())
df = pd.DataFrame(data)
print("Columns in dataset:", df.columns)
print("Sample data:")
print(df.head())
# Out:
# Columns in dataset: Index(['_id', 'adevinta_brand', 'agentDetails', 'agentUrl', 'firstSeen',
#        'firstSeenNewerDate', 'lastSeen', 'lastUseForExportViaJSON', 'location',
#        'logo', 'oldAgentData', 'onlineHistory', 'online_store_id',
#        'online_store_name', 'owner', 'agentDetailsUpdated', 'toBeAggregated',
#        'url', 'phone', 'newDocToBeAggregated', 'offerer_email', 'offerer_id',
#        'offerer_json', 'offerer_location_city', 'offerer_location_street',
#        'offerer_location_zip', 'offerer_name', 'offerer_phoneNumber',
#        'offerer_platformUrl', 'offerer_website', 'accountType', 'company',
#        'contact', 'dataFromUser', 'display_name', 'emailMd5',
#        'hasAgencyFeesContent', 'hasEmail', 'id', 'imageName', 'namespace',
#        'position', 'website', 'affiliation', 'agencyBackgroundImage',
#        'agencyFeeUrl', 'agencyPageEnabled', 'canUseSkypeContact',
#        'dataFromImport', 'description', 'displayLogoOnSearchPage', 'facebook',
#        'highlightedOnMap', 'instagram', 'legalNotices', 'linkedin',
#        'openingHours', 'twitter'],
#       dtype='object')
# Sample data:
#                                     _id adevinta_brand  \
# 0  000831c2-c7b9-485b-a104-efdb215889ab      leboncoin
# 1  0031a728-5c6a-43ef-881f-f9e3a023b4e0      leboncoin
# 2  0043332c-d7a1-4c69-b874-414cd2de25dc      leboncoin
# 3  007544c7-e3b6-4c90-80d7-5873bcaeca49      leboncoin
# 4  00998197-af80-4b1e-8c37-d907f4bd9015      leboncoin
#
#                                         agentDetails  \
# 0  {'_sentryTraceData': '2fa7be71be479d422b15d975...
# 1  {'_sentryTraceData': '4d80663a63c863f369a6b48f...
# 2  {'_sentryTraceData': 'f17bf75d7d8802eb60601fd9...
# 3  {'_sentryTraceData': '9c377a4c9a694e5c3373c542...
# 4  {'_sentryTraceData': '631d4f7a1d2c4ea61f5486c2...
#
#                                             agentUrl               firstSeen  \
# 0  https://www.leboncoin.fr/boutique/1204185/Bére... 2023-10-25 07:55:22.089
# 1  https://www.leboncoin.fr/boutique/1602955/EAPR... 2023-10-23 21:05:26.739
# 2  https://www.leboncoin.fr/boutique/6784598/GROU... 2024-10-01 19:11:56.510
# 3  https://www.leboncoin.fr/boutique/2799963/HABI... 2023-09-26 00:34:48.836
# 4  https://www.leboncoin.fr/boutique/50687/RESEAU... 2023-10-23 22:04:52.528
#
#        firstSeenNewerDate                lastSeen lastUseForExportViaJSON  \
# 0 2024-03-29 11:59:31.481 2025-02-11 04:28:15.930 2025-02-11 06:08:40.784
# 1 2024-03-29 15:55:50.215 2025-02-11 04:22:24.452 2025-02-11 05:58:28.148
# 2                     NaT 2025-02-11 04:17:15.064 2025-02-11 05:52:12.846
# 3 2024-03-29 12:32:13.911 2025-02-11 04:35:24.570 2025-02-11 05:51:34.795
# 4 2024-03-29 12:04:52.401 2025-02-11 04:42:37.573 2025-02-11 05:03:43.571
#
#                                             location  \
# 0  {'city': 'PARIS', 'region': '12', 'region_labe...
# 1  {'city': 'Paris', 'region': '12', 'region_labe...
# 2  {'city': 'Paris', 'region': '12', 'region_labe...
# 3  {'city': 'Paris', 'region': '12', 'region_labe...
# 4  {'city': 'Paris 16e Arrondissement', 'region':...
#
#                                                 logo  ... dataFromImport  \
# 0  {'thumbnail': 'https://img.leboncoin.fr/api/v1...  ...            NaN
# 1  {'thumbnail': 'https://img.leboncoin.fr/api/v1...  ...            NaN
# 2  {'thumbnail': 'https://img.leboncoin.fr/api/v1...  ...            NaN
# 3  {'thumbnail': 'https://img.leboncoin.fr/api/v1...  ...            NaN
# 4  {'thumbnail': 'https://img.leboncoin.fr/api/v1...  ...            NaN
#
#   description  displayLogoOnSearchPage facebook highlightedOnMap instagram  \
# 0         NaN                      NaN      NaN              NaN       NaN
# 1         NaN                      NaN      NaN              NaN       NaN
# 2         NaN                      NaN      NaN              NaN       NaN
# 3         NaN                      NaN      NaN              NaN       NaN
# 4         NaN                      NaN      NaN              NaN       NaN
#
#    legalNotices linkedin openingHours twitter
# 0           NaN      NaN          NaN     NaN
# 1           NaN      NaN          NaN     NaN
# 2           NaN      NaN          NaN     NaN
# 3           NaN      NaN          NaN     NaN
# 4           NaN      NaN          NaN     NaN
#
# [5 rows x 58 columns]

# %% [markdown]
# ## 3. Flatten Nested Documents
#
# Many of the records contain nested documents. Use `pandas.json_normalize` to flatten these structures. This step converts nested keys into a single level using a separator (e.g., `.`).

# %%
# Flatten the nested JSON data
df = pd.json_normalize(data, sep='.')
print("Columns after flattening:", df.columns.tolist())
display(df.head())
# Out:
# Columns after flattening: ['_id', 'adevinta_brand', 'agentUrl', 'firstSeen', 'firstSeenNewerDate', 'lastSeen', 'lastUseForExportViaJSON', 'onlineHistory', 'online_store_id', 'online_store_name', 'agentDetailsUpdated', 'toBeAggregated', 'url', 'phone', 'agentDetails._sentryTraceData', 'agentDetails._sentryBaggage', 'agentDetails.data.online_store_id', 'agentDetails.data.online_store_name', 'agentDetails.data.logo.thumbnail', 'agentDetails.data.logo.small', 'agentDetails.data.logo.large', 'agentDetails.data.adevinta_brand', 'agentDetails.data.address', 'agentDetails.data.zipcode', 'agentDetails.data.city', 'agentDetails.data.slogan', 'agentDetails.data.description', 'agentDetails.data.website_url', 'agentDetails.data.owner.userId', 'agentDetails.data.owner.activitySectorID', 'agentDetails.data.owner.activitySector', 'agentDetails.data.owner.categoryId', 'agentDetails.data.owner.siren', 'agentDetails.data.owner.siret', 'agentDetails.data.owner.storeId', 'agentDetails.data.owner.activeSince', 'agentDetails.data.location.address', 'agentDetails.data.location.district', 'agentDetails.data.location.city', 'agentDetails.data.location.label', 'agentDetails.data.location.lat', 'agentDetails.data.location.lng', 'agentDetails.data.location.zipcode', 'agentDetails.data.location.geo_source', 'agentDetails.data.location.geo_provider', 'agentDetails.data.location.region', 'agentDetails.data.location.region_label', 'agentDetails.data.location.department', 'agentDetails.data.location.dpt_label', 'agentDetails.data.location.country', 'agentDetails.data.location.shape.type', 'agentDetails.data.location.shape.coordinates', 'agentDetails.data.hide_phone', 'agentDetails.data.hide_address', 'agentDetails.data.hide_contact_form', 'agentDetails.data.rating.rating_value', 'agentDetails.data.rating.user_ratings_total', 'agentDetails.data.rating.source', 'agentDetails.data.rating.source_display', 'agentDetails.data.rating.retrieval_time', 'agentDetails.data.rating.reviews', 'agentDetails.data.rating.url', 'agentDetails.data.pictures', 'agentDetails.data.cover', 'agentDetails.data.team_member_portraits', 'agentDetails.data.team_members', 'agentDetails.data.media.image_id', 'agentDetails.data.media.title', 'agentDetails.data.media.link_url', 'agentDetails.data.media_image_url', 'agentDetails.data.activity_zone.radius', 'agentDetails.data.activity_zone.location.address', 'agentDetails.data.activity_zone.location.district', 'agentDetails.data.activity_zone.location.city', 'agentDetails.data.activity_zone.location.label', 'agentDetails.data.activity_zone.location.lat', 'agentDetails.data.activity_zone.location.lng', 'agentDetails.data.activity_zone.location.zipcode', 'agentDetails.data.activity_zone.location.geo_source', 'agentDetails.data.activity_zone.location.geo_provider', 'agentDetails.data.activity_zone.location.region', 'agentDetails.data.activity_zone.location.region_label', 'agentDetails.data.activity_zone.location.department', 'agentDetails.data.activity_zone.location.dpt_label', 'agentDetails.data.activity_zone.location.country', 'agentDetails.data.prestations', 'agentDetails.defaultSearchOptions.limit', 'agentDetails.defaultSearchOptions.filters.owner.user_id', 'agentDetails.defaultSearchOptions.filters.enums.ad_type', 'agentDetails.defaultSearchOptions.filters.keywords.text', 'agentDetails.defaultSearchOptions.filters.category.id', 'agentDetails.adsData.total', 'agentDetails.adsData.total_all', 'agentDetails.adsData.total_pro', 'agentDetails.adsData.total_private', 'agentDetails.adsData.total_active', 'agentDetails.adsData.total_inactive', 'agentDetails.adsData.total_shippable', 'agentDetails.adsData.max_pages', 'agentDetails.adsData.referrer_id', 'agentDetails.adsData.pivot', 'agentDetails.adsData.ads', 'agentDetails.adsData.applied_condition', 'agentDetails.adsData.human_readable_applied_condition', 'agentDetails.i18n.namespaces.account/rating-output.rating.automatic-score.text', 'agentDetails.i18n.namespaces.account/rating-output.rating.autorat ...
#                                     _id adevinta_brand  \
# 0  000831c2-c7b9-485b-a104-efdb215889ab      leboncoin
# 1  0031a728-5c6a-43ef-881f-f9e3a023b4e0      leboncoin
# 2  0043332c-d7a1-4c69-b874-414cd2de25dc      leboncoin
# 3  007544c7-e3b6-4c90-80d7-5873bcaeca49      leboncoin
# 4  00998197-af80-4b1e-8c37-d907f4bd9015      leboncoin
#
#                                             agentUrl               firstSeen  \
# 0  https://www.leboncoin.fr/boutique/1204185/Bére... 2023-10-25 07:55:22.089
# 1  https://www.leboncoin.fr/boutique/1602955/EAPR... 2023-10-23 21:05:26.739
# 2  https://www.leboncoin.fr/boutique/6784598/GROU... 2024-10-01 19:11:56.510
# 3  https://www.leboncoin.fr/boutique/2799963/HABI... 2023-09-26 00:34:48.836
# 4  https://www.leboncoin.fr/boutique/50687/RESEAU... 2023-10-23 22:04:52.528
#
#        firstSeenNewerDate                lastSeen lastUseForExportViaJSON  \
# 0 2024-03-29 11:59:31.481 2025-02-11 04:28:15.930 2025-02-11 06:08:40.784
# 1 2024-03-29 15:55:50.215 2025-02-11 04:22:24.452 2025-02-11 05:58:28.148
# 2                     NaT 2025-02-11 04:17:15.064 2025-02-11 05:52:12.846
# 3 2024-03-29 12:32:13.911 2025-02-11 04:35:24.570 2025-02-11 05:51:34.795
# 4 2024-03-29 12:04:52.401 2025-02-11 04:42:37.573 2025-02-11 05:03:43.571
#
#                                        onlineHistory  online_store_id  \
# 0  [{'interval': {'start': 2024-03-29 11:59:31.48...        1204185.0
# 1  [{'interval': {'start': 2024-03-29 15:55:50.21...        1602955.0
# 2  [{'interval': {'start': 2024-10-01 19:11:56.51...        6784598.0
# 3  [{'interval': {'start': 2024-03-29 12:32:13.91...        2799963.0
# 4  [{'interval': {'start': 2024-03-29 12:04:52.40...          50687.0
#
#        online_store_name  ... position.automatic.lat  position.automatic.lng  \
# 0  Bérengère PLANTECOSTE  ...                    NaN                     NaN
# 1                  EAPRD  ...                    NaN                     NaN
# 2   GROUPE SM IMMOBILIER  ...                    NaN                     NaN
# 3         HABITAT PROJET  ...                    NaN                     NaN
# 4         RESEAU BROKERS  ...                    NaN                     NaN
#
#   company.photoWatermarkAlias dataFromUser.company.photoWatermarkAlias  \
# 0                         NaN                                      NaN
# 1                         NaN                                      NaN
# 2                         NaN                                      NaN
# 3                         NaN                                      NaN
# 4                         NaN                                      NaN
#
#   dataFromImport.company.rcs dataFromImport.company.cardNumber  dataFromUser  \
# 0                        NaN                               NaN           NaN
# 1                        NaN                               NaN           NaN
# 2                        NaN                               NaN           NaN
# 3                        NaN                               NaN           NaN
# 4                        NaN                               NaN           NaN
#
#   contact.name dataFromUser.contact.name dataFromImport.affiliation
# 0          NaN                       NaN                        NaN
# 1          NaN                       NaN                        NaN
# 2          NaN                       NaN                        NaN
# 3          NaN                       NaN                        NaN
# 4          NaN                       NaN                        NaN
#
# [5 rows x 2021 columns]

# %%
df.head()
# Out:
#                                     _id adevinta_brand  \
# 0  000831c2-c7b9-485b-a104-efdb215889ab      leboncoin
# 1  0031a728-5c6a-43ef-881f-f9e3a023b4e0      leboncoin
# 2  0043332c-d7a1-4c69-b874-414cd2de25dc      leboncoin
# 3  007544c7-e3b6-4c90-80d7-5873bcaeca49      leboncoin
# 4  00998197-af80-4b1e-8c37-d907f4bd9015      leboncoin
#
#                                             agentUrl               firstSeen  \
# 0  https://www.leboncoin.fr/boutique/1204185/Bére... 2023-10-25 07:55:22.089
# 1  https://www.leboncoin.fr/boutique/1602955/EAPR... 2023-10-23 21:05:26.739
# 2  https://www.leboncoin.fr/boutique/6784598/GROU... 2024-10-01 19:11:56.510
# 3  https://www.leboncoin.fr/boutique/2799963/HABI... 2023-09-26 00:34:48.836
# 4  https://www.leboncoin.fr/boutique/50687/RESEAU... 2023-10-23 22:04:52.528
#
#        firstSeenNewerDate                lastSeen lastUseForExportViaJSON  \
# 0 2024-03-29 11:59:31.481 2025-02-11 04:28:15.930 2025-02-11 06:08:40.784
# 1 2024-03-29 15:55:50.215 2025-02-11 04:22:24.452 2025-02-11 05:58:28.148
# 2                     NaT 2025-02-11 04:17:15.064 2025-02-11 05:52:12.846
# 3 2024-03-29 12:32:13.911 2025-02-11 04:35:24.570 2025-02-11 05:51:34.795
# 4 2024-03-29 12:04:52.401 2025-02-11 04:42:37.573 2025-02-11 05:03:43.571
#
#                                        onlineHistory  online_store_id  \
# 0  [{'interval': {'start': 2024-03-29 11:59:31.48...        1204185.0
# 1  [{'interval': {'start': 2024-03-29 15:55:50.21...        1602955.0
# 2  [{'interval': {'start': 2024-10-01 19:11:56.51...        6784598.0
# 3  [{'interval': {'start': 2024-03-29 12:32:13.91...        2799963.0
# 4  [{'interval': {'start': 2024-03-29 12:04:52.40...          50687.0
#
#        online_store_name  ... position.automatic.lat  position.automatic.lng  \
# 0  Bérengère PLANTECOSTE  ...                    NaN                     NaN
# 1                  EAPRD  ...                    NaN                     NaN
# 2   GROUPE SM IMMOBILIER  ...                    NaN                     NaN
# 3         HABITAT PROJET  ...                    NaN                     NaN
# 4         RESEAU BROKERS  ...                    NaN                     NaN
#
#   company.photoWatermarkAlias dataFromUser.company.photoWatermarkAlias  \
# 0                         NaN                                      NaN
# 1                         NaN                                      NaN
# 2                         NaN                                      NaN
# 3                         NaN                                      NaN
# 4                         NaN                                      NaN
#
#   dataFromImport.company.rcs dataFromImport.company.cardNumber  dataFromUser  \
# 0                        NaN                               NaN           NaN
# 1                        NaN                               NaN           NaN
# 2                        NaN                               NaN           NaN
# 3                        NaN                               NaN           NaN
# 4                        NaN                               NaN           NaN
#
#   contact.name dataFromUser.contact.name dataFromImport.affiliation
# 0          NaN                       NaN                        NaN
# 1          NaN                       NaN                        NaN
# 2          NaN                       NaN                        NaN
# 3          NaN                       NaN                        NaN
# 4          NaN                       NaN                        NaN
#
# [5 rows x 2021 columns]

# %% [markdown]
# # 4. Data Cleaning
# Define a helper function to normalize text (e.g., lowercasing and trimming)

# %%
def normalize_text(text):
    if pd.isnull(text):
        return ""
    text = text.lower().strip()
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    return text

# %% [markdown]
# ## Normalize key columns – adjust column names based on your dataset structure.

# %%
df['name_norm']    = df['agentDetails.data.online_store_name'].apply(normalize_text)
df['phone_norm']   = df['phone'].apply(normalize_text)
df['email_norm']   = df['offerer_email'].apply(normalize_text)
df['company_norm'] = df['agentDetails.data.online_store_name'].apply(normalize_text)
df['address_norm'] = df['agentDetails.data.address'].apply(normalize_text)

# %% [markdown]
# # 5. Deduplication using Fuzzy Matching
#     This example uses fuzzy matching on the normalized agent names.

# %%
duplicates = set()
threshold = 90  # Adjust this threshold as necessary

for i in range(len(df)):
    if i in duplicates:
        continue  # Skip already flagged duplicates
    for j in range(i + 1, len(df)):
        if j in duplicates:
            continue
        score = fuzz.ratio(df.loc[i, 'name_norm'], df.loc[j, 'name_norm'])
        if score >= threshold:
            duplicates.add(j)

# %% [markdown]
# # Create a deduplicated DataFrame by removing duplicate records

# %%
dedup_df = df.drop(duplicates)
print("Original record count:", len(df))
print("Deduplicated record count:", len(dedup_df))
# Out:
# Original record count: 5702
# Deduplicated record count: 1288

# %% [markdown]
# # 6. Save the Cleaned & Deduplicated Data

# %%
dedup_df.to_csv("deduplicated_agents_4.csv", index=False)
print("Deduplicated dataset saved as 'deduplicated_agents_4.csv'")
# Out:
# Deduplicated dataset saved as 'deduplicated_agents_4.csv'
